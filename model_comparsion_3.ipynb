# %%
from models import *
from evaluate import *
import os
from keras.callbacks import EarlyStopping
from torch.utils.data import Dataset, DataLoader
import random
# 设置随机种子
seed = 42  # 你可以更改为任意整数
os.environ['PYTHONHASHSEED'] = str(seed)  # 影响 Python 内部哈希算法的随机性
random.seed(seed)  # 固定 Python 的随机性
np.random.seed(seed)  # 固定 NumPy 的随机性
tf.random.set_seed(seed)  # 固定 TensorFlow 的随机性

# 确保 TensorFlow 计算图的确定性
tf.config.experimental.enable_op_determinism()

# 配置 TensorFlow 以获得确定性行为
os.environ["TF_DETERMINISTIC_OPS"] = "1"

# 关闭 GPU 计算中的非确定性优化（如 cuDNN）
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
# Out:
# C:\Users\xyang\AppData\Roaming\Python\Python38\site-packages\tensorflow_addons\utils\ensure_tf_install.py:53: UserWarning: Tensorflow Addons supports using Python ops for all Tensorflow versions above or equal to 2.6.0 and strictly below 2.9.0 (nightly versions are not supported).
#  The versions of TensorFlow you are currently using is 2.12.0 and is not supported.
# Some things might work, some things might not.
# If you were to encounter a bug, do not file an issue.
# If you want to make sure you're using a tested and supported configuration, either change the TensorFlow version or the TensorFlow Addons's version.
# You can find the compatibility matrix in TensorFlow Addon's readme:
# https://github.com/tensorflow/addons
#   warnings.warn(

# %%
def transform_labels(y_train, y_test):
    """
    Transform label to min equal zero and continuous
    For example if we have [1,3,4] ---> [0,1,2]


    Parameters
    ----------
    y_train: array
        Labels of the train set

    y_test: array
        Labels of the test set


    Returns
    -------
    new_y_train: array
        Transformed y_train array

    new_y_test: array
        Transformed y_test array
    """

    # Initiate the encoder
    encoder = LabelEncoder()

    # Concatenate train and test to fit
    y_train_test = np.concatenate((y_train, y_test), axis=0)

    # Fit the encoder
    encoder.fit(y_train_test.ravel())

    # Transform to min zero and continuous labels
    new_y_train_test = encoder.transform(y_train_test.ravel())

    # Resplit the train and test
    new_y_train = new_y_train_test[0 : len(y_train)]
    new_y_test = new_y_train_test[len(y_train) :]

    return new_y_train, new_y_test

# %%
path=r'data'
X = np.load(path + "/X.npy")
y = np.load(path + "/y.npy")

# %%
import tensorflow as tf
from tensorflow.keras.layers import Dense, Layer

class CrossAttention(tf.keras.layers.Layer):
    def __init__(self, embed_dim, num_heads, **kwargs):
        super(CrossAttention, self).__init__(**kwargs)
        self.embed_dim = embed_dim
        self.num_heads = num_heads
        self.query_dense = Dense(embed_dim)
        self.key_dense = Dense(embed_dim)
        self.value_dense = Dense(embed_dim)

    def call(self, inputs):
        Q, K, V = inputs
        batch_size = tf.shape(Q)[0]
        seq_len_Q = tf.shape(Q)[1]
        seq_len_K = tf.shape(K)[1]
        # print(Q.shape,K.shape,V.shape,2226)
        # 计算 Q, K, V
        Q = self.query_dense(Q)
        K = self.key_dense(K)
        V = self.value_dense(V)
        # print(Q.shape,K.shape,V.shape,2227)
        # 分成多个头
        Q = self.split_heads(Q, batch_size)
        K = self.split_heads(K, batch_size)
        V = self.split_heads(V, batch_size)
        # print(Q.shape,K.shape,V.shape,2228)
        # 计算注意力分数
        scores = tf.matmul(Q, K, transpose_b=True) / tf.math.sqrt(tf.cast(self.embed_dim // self.num_heads, tf.float32))
        # print(scores.shape,1115)
        # 计算注意力权重
        attention_weights = tf.nn.softmax(scores, axis=-1)
        
        # 计算注意力输出
        context = tf.matmul(attention_weights, V)
        # print(context.shape,1118)
        context = self.combine_heads(context, batch_size)
        
        return context
    


    def split_heads(self, x, batch_size):
        depth = self.embed_dim // self.num_heads
        x = tf.reshape(x, (batch_size, -1, self.num_heads, depth))
        return tf.transpose(x, perm=[0, 2, 1, 3])

    def combine_heads(self, x, batch_size):
        x = tf.transpose(x, perm=[0, 2, 1, 3])
        x = tf.reshape(x, (batch_size, -1, self.embed_dim))
        return x


def stcan_model1(input_shape, n_class, embed_dim=512, num_heads=1):
    n = input_shape[0]
    print(n,1111)
    k = input_shape[1]
    print(k,1112)
    input_layer = Input(shape=(n, k, 1))

    # 2D convolution layers
    a = Conv2D(
        filters=64,
        kernel_size=(n, 1),
        strides=(1, 1),
        padding="same",
        input_shape=(n, k, 1),
        name="2D",
    )(input_layer)
    a = BatchNormalization()(a)
    a = Activation("relu", name="2D_Activation")(a)
    a = Conv2D(filters=1, kernel_size=(1, 1), strides=(1, 1))(a)
    a = Activation("relu", name="2D_Reduced_Activation")(a) 
    x = Reshape((n, k))(a)

    # 1D convolution layers
    b = Reshape((n, k))(input_layer)
    b = LSTM(100, return_sequences=True)(b)
    b = LSTM(1, return_sequences=True)(b)
    b = BatchNormalization()(b)
    y = Activation("relu", name="1D_Activation")(b)


    # Cross-Attention
    z = CrossAttention(embed_dim, num_heads)([y,x,x])
    print(x.shape,y.shape,z.shape,1113)
    z = GlobalAveragePooling1D()(z)
    output_layer = Dense(n_class, activation="softmax")(z)

    model = Model(input_layer, output_layer)
    focal_loss = tfa.losses.SigmoidFocalCrossEntropy(alpha=0.5, gamma=4.0)
    model.compile(loss=focal_loss, metrics=["AUC"], optimizer='sgd')
    return model

# %%
def stcan_model2(input_shape, n_class, embed_dim=512, num_heads=1):
    n = input_shape[0]
    # print(n,1111)
    k = input_shape[1]
    # print(k,1112)
    input_layer = Input(shape=(n, k, 1))

    # 2D convolution layers
    a = Conv2D(
        filters=64,
        kernel_size=(n, 1),
        strides=(1, 1),
        padding="same",
        input_shape=(n, k, 1),
        name="2D",
    )(input_layer)
    a = BatchNormalization()(a)
    a = Activation("relu", name="2D_Activation")(a)
    a = Conv2D(filters=1, kernel_size=(1, 1), strides=(1, 1))(a)
    a = Activation("relu", name="2D_Reduced_Activation")(a) 
    x = Reshape((n, k))(a)

    # 1D convolution layers
    b = Reshape((n, k))(input_layer)
    b = LSTM(100, return_sequences=True)(b)
    b = LSTM(1, return_sequences=True)(b)
    b = BatchNormalization()(b)
    y = Activation("relu", name="1D_Activation")(b)


    # Cross-Attention
    # z = CrossAttention(embed_dim, num_heads)([y,x,x])
    # Cross-Attention
    z = CrossAttention(embed_dim, num_heads)([x,y,y])
    # print(x.shape,y.shape,z.shape,1113)
    # Reshape z to fit Conv2D
    # z = Reshape((z.shape[1], z.shape[2], 1))(z)
    
    # Add Conv2D classifier
    z_reshaped = Reshape((n, 1, embed_dim))(z)
    # print(z_reshaped.shape,1114)
    # Conv2D layers for classification
    z_conv = Conv2D(filters=32, kernel_size=(3, 3), padding='same', activation='relu')(z_reshaped)
    z_conv = Flatten()(z_conv)
    output_layer = Dense(n_class, activation='softmax')(z_conv)
    
    model = Model(inputs=input_layer, outputs=output_layer)
    focal_loss = tfa.losses.SigmoidFocalCrossEntropy(alpha=0.5, gamma=4.0)
    model.compile(loss=focal_loss, metrics=["AUC"], optimizer='sgd')
    return model

# %%
input_shape = (7, 55)
n_class = 2
model = stcan_model(input_shape, n_class)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 7, 55, 1)]   0           []
#
#  2D (Conv2D)                    (None, 7, 55, 64)    128         ['input_1[0][0]']
#
#  batch_normalization (BatchNorm  (None, 7, 55, 64)   256         ['2D[0][0]']
#  alization)
#
#  reshape_1 (Reshape)            (None, 7, 55)        0           ['input_1[0][0]']
#
#  2D_Activation (Activation)     (None, 7, 55, 64)    0           ['batch_normalization[0][0]']
#
#  lstm (LSTM)                    (None, 7, 100)       62400       ['reshape_1[0][0]']
#
#  conv2d (Conv2D)                (None, 7, 55, 1)     65          ['2D_Activation[0][0]']
#
#  lstm_1 (LSTM)                  (None, 7, 1)         408         ['lstm[0][0]']
#
#  2D_Reduced_Activation (Activat  (None, 7, 55, 1)    0           ['conv2d[0][0]']
#  ion)
#
#  batch_normalization_1 (BatchNo  (None, 7, 1)        4           ['lstm_1[0][0]']
#  rmalization)
#
#  reshape (Reshape)              (None, 7, 55)        0           ['2D_Reduced_Activation[0][0]']
#
#  1D_Activation (Activation)     (None, 7, 1)         0           ['batch_normalization_1[0][0]']
#
#  cross_attention (CrossAttentio  (None, None, 512)   293376      ['reshape[0][0]',
#  n)                                                               '1D_Activation[0][0]',
#                                                                   '1D_Activation[0][0]']
#
#  global_average_pooling1d (Glob  (None, 512)         0           ['cross_attention[0][0]']
#  alAveragePooling1D)
#
#  dense_4 (Dense)                (None, 2)            1026        ['global_average_pooling1d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 357,663
# Trainable params: 357,533
# Non-trainable params: 130
# __________________________________________________________________________________________________

# %%
stcan2 = stcan_model2(input_shape, n_class=2,embed_dim=55,num_heads=5)
models={'stcan2':stcan2}

# %%
model_eval_train = pd.DataFrame({},[])
model_eval_test = pd.DataFrame({},[])

# %%
from sklearn.model_selection import StratifiedKFold
import os
import numpy as np
import keras
from keras.callbacks import EarlyStopping, ModelCheckpoint

# 设定随机种子
seed = 5
np.random.seed(seed)

# 5折交叉验证
num_folds = 5
skf = StratifiedKFold(n_splits=num_folds, shuffle=True, random_state=seed)

# 存储模型的评估结果
accuracy_list = []
f1_list = []
roc_auc_list = []
mcc_list = []

for fold, (train_idx, val_idx) in enumerate(skf.split(X, y)):
    print(f'Fold {fold + 1}/{num_folds}')

    # 划分训练集和验证集
    X_train, X_val = X[train_idx], X[val_idx]
    y_train, y_val = y[train_idx], y[val_idx]
    y_train, y_val = transform_labels(y_train, y_val)
    y_train_nonencoded, y_val_nonencoded = y_train, y_val

    # One hot encoding of the labels
    enc = OneHotEncoder()
    enc.fit(np.concatenate((y_train, y_val), axis=0).reshape(-1, 1))
    y_train = enc.transform(y_train.reshape(-1, 1)).toarray()
    y_val = enc.transform(y_val.reshape(-1, 1)).toarray()
    X_train = np.reshape(
        np.array(X_train),
        (X_train.shape[0], X_train.shape[1], X_train.shape[2], 1),
        order="C",
    )
    X_val = np.reshape(
        np.array(X_val),
        (X_val.shape[0], X_val.shape[1], X_val.shape[2], 1),
        order="C",
)

    for name, model in models.items():
        print(name, model, "Training in Fold:", fold + 1)

        # 创建模型保存路径
        path1 = f'best_model/{name}/'
        path2 = f"{fold}/best_weights.hdf5"
        best_weights_filepath = os.path.join(path1, path2)
        os.makedirs(os.path.dirname(best_weights_filepath), exist_ok=True)

        # 训练时使用早停法
        monitor = EarlyStopping(monitor='val_auc', min_delta=1e-5, patience=50, verbose=1, mode='max')
        saveBestModel = ModelCheckpoint(best_weights_filepath, monitor='val_auc', verbose=1, save_best_only=True, mode='max')

        # 训练模型
        h = model.fit(X_train, y_train,
                      callbacks=[monitor, saveBestModel],
                      validation_data=(X_val, y_val),
                      epochs=1000, batch_size=32, verbose=1)

        # 载入当前折最佳权重
        model.load_weights(best_weights_filepath)

        # 评估模型
        model_eval_train, model_eval_test, cf_matrix_train, cf_matrix_test = model_eval_data(
            model, X_train, y_train_nonencoded, 
            X_val, y_val_nonencoded, 
            model_eval_train, model_eval_test, 
            Name=str(fold)+'_'+name
        )

        # 计算当前折的指标
        accuracy = accuracy_score(y_val_nonencoded, model.predict(X_val).argmax(axis=1))
        f1 = f1_score(y_val_nonencoded, model.predict(X_val).argmax(axis=1))
        roc_auc = roc_auc_score(y_val_nonencoded, model.predict(X_val)[:, 1])
        mcc = matthews_corrcoef(y_val_nonencoded, model.predict(X_val).argmax(axis=1))

        accuracy_list.append(accuracy)
        f1_list.append(f1)
        roc_auc_list.append(roc_auc)
        mcc_list.append(mcc)

# 计算五折交叉验证的平均指标
print("\nFinal 5-Fold Cross-Validation Results:")
print(f'Average Accuracy: {np.mean(accuracy_list):.4f} ± {np.std(accuracy_list):.4f}')
print(f'Average F1 Score: {np.mean(f1_list):.4f} ± {np.std(f1_list):.4f}')
print(f'Average ROC AUC: {np.mean(roc_auc_list):.4f} ± {np.std(roc_auc_list):.4f}')
print(f'Average MCC: {np.mean(mcc_list):.4f} ± {np.std(mcc_list):.4f}')
# Out:
# Fold 1/5
# stcan2 <keras.engine.functional.Functional object at 0x00000236D9C3A580> Training in Fold: 1
# Epoch 1/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0406 - auc: 0.6730
# Epoch 1: val_auc improved from -inf to 0.68020, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 5s 34ms/step - loss: 0.0406 - auc: 0.6739 - val_loss: 0.0401 - val_auc: 0.6802
# Epoch 2/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0397 - auc: 0.7021
# Epoch 2: val_auc did not improve from 0.68020
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0396 - auc: 0.7027 - val_loss: 0.0403 - val_auc: 0.6802
# Epoch 3/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0391 - auc: 0.7202
# Epoch 3: val_auc improved from 0.68020 to 0.68193, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0391 - auc: 0.7201 - val_loss: 0.0408 - val_auc: 0.6819
# Epoch 4/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0390 - auc: 0.7204
# Epoch 4: val_auc improved from 0.68193 to 0.72155, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0390 - auc: 0.7208 - val_loss: 0.0406 - val_auc: 0.7215
# Epoch 5/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0383 - auc: 0.7413
# Epoch 5: val_auc improved from 0.72155 to 0.74771, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0384 - auc: 0.7400 - val_loss: 0.0410 - val_auc: 0.7477
# Epoch 6/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0375 - auc: 0.7629
# Epoch 6: val_auc did not improve from 0.74771
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0375 - auc: 0.7616 - val_loss: 0.0434 - val_auc: 0.5071
# Epoch 7/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0370 - auc: 0.7692
# Epoch 7: val_auc improved from 0.74771 to 0.78306, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0370 - auc: 0.7695 - val_loss: 0.0380 - val_auc: 0.7831
# Epoch 8/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0370 - auc: 0.7707
# Epoch 8: val_auc did not improve from 0.78306
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0370 - auc: 0.7717 - val_loss: 0.0497 - val_auc: 0.6915
# Epoch 9/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0359 - auc: 0.7900
# Epoch 9: val_auc did not improve from 0.78306
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0359 - auc: 0.7890 - val_loss: 0.0487 - val_auc: 0.6906
# Epoch 10/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0353 - auc: 0.7987
# Epoch 10: val_auc improved from 0.78306 to 0.80146, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0353 - auc: 0.7983 - val_loss: 0.0403 - val_auc: 0.8015
# Epoch 11/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0353 - auc: 0.8006
# Epoch 11: val_auc did not improve from 0.80146
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0353 - auc: 0.8004 - val_loss: 1.5013 - val_auc: 0.4197
# Epoch 12/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0370 - auc: 0.7696
# Epoch 12: val_auc did not improve from 0.80146
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0370 - auc: 0.7687 - val_loss: 0.0569 - val_auc: 0.6802
# Epoch 13/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0360 - auc: 0.7878
# Epoch 13: val_auc did not improve from 0.80146
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0360 - auc: 0.7872 - val_loss: 3.0695 - val_auc: 0.3849
# Epoch 14/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0339 - auc: 0.8217
# Epoch 14: val_auc did not improve from 0.80146
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0339 - auc: 0.8220 - val_loss: 2.0312 - val_auc: 0.4497
# Epoch 15/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0360 - auc: 0.7910
# Epoch 15: val_auc did not improve from 0.80146
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0360 - auc: 0.7916 - val_loss: 0.0560 - val_auc: 0.6802
# Epoch 16/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0333 - auc: 0.8304
# Epoch 16: val_auc improved from 0.80146 to 0.85983, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0333 - auc: 0.8299 - val_loss: 0.0311 - val_auc: 0.8598
# Epoch 17/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - auc: 0.8587
# Epoch 17: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0312 - auc: 0.8576 - val_loss: 2.2914 - val_auc: 0.4518
# Epoch 18/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0318 - auc: 0.8499
# Epoch 18: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0318 - auc: 0.8494 - val_loss: 3.9442 - val_auc: 0.3206
# Epoch 19/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0330 - auc: 0.8338
# Epoch 19: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0331 - auc: 0.8317 - val_loss: 0.0640 - val_auc: 0.6802
# Epoch 20/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0311 - auc: 0.8595
# Epoch 20: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0311 - auc: 0.8603 - val_loss: 0.0431 - val_auc: 0.8393
# Epoch 21/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0327 - auc: 0.8404
# Epoch 21: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0327 - auc: 0.8400 - val_loss: 1.4953 - val_auc: 0.4600
# Epoch 22/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0296 - auc: 0.8747
# Epoch 22: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0296 - auc: 0.8747 - val_loss: 0.0524 - val_auc: 0.8233
# Epoch 23/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0308 - auc: 0.8625
# Epoch 23: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0308 - auc: 0.8603 - val_loss: 0.8144 - val_auc: 0.4614
# Epoch 24/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0302 - auc: 0.8696
# Epoch 24: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0302 - auc: 0.8692 - val_loss: 2.0373 - val_auc: 0.4577
# Epoch 25/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0304 - auc: 0.8663
# Epoch 25: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0304 - auc: 0.8653 - val_loss: 0.0593 - val_auc: 0.5909
# Epoch 26/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0299 - auc: 0.8710
# Epoch 26: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0299 - auc: 0.8719 - val_loss: 0.4929 - val_auc: 0.4631
# Epoch 27/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0309 - auc: 0.8614
# Epoch 27: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0309 - auc: 0.8616 - val_loss: 0.8303 - val_auc: 0.4647
# Epoch 28/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0295 - auc: 0.8749
# Epoch 28: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0295 - auc: 0.8751 - val_loss: 1.4155 - val_auc: 0.4639
# Epoch 29/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0308 - auc: 0.8619
# Epoch 29: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0308 - auc: 0.8610 - val_loss: 2.0829 - val_auc: 0.4661
# Epoch 30/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0288 - auc: 0.8828
# Epoch 30: val_auc did not improve from 0.85983
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0288 - auc: 0.8830 - val_loss: 0.0319 - val_auc: 0.8564
# Epoch 31/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0295 - auc: 0.8758
# Epoch 31: val_auc improved from 0.85983 to 0.88483, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0295 - auc: 0.8765 - val_loss: 0.0296 - val_auc: 0.8848
# Epoch 32/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0292 - auc: 0.8781
# Epoch 32: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0292 - auc: 0.8785 - val_loss: 0.0665 - val_auc: 0.7990
# Epoch 33/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0300 - auc: 0.8703
# Epoch 33: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0300 - auc: 0.8703 - val_loss: 0.0311 - val_auc: 0.8726
# Epoch 34/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0286 - auc: 0.8843
# Epoch 34: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0287 - auc: 0.8841 - val_loss: 0.5805 - val_auc: 0.4661
# Epoch 35/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0277 - auc: 0.8931
# Epoch 35: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0278 - auc: 0.8908 - val_loss: 0.3931 - val_auc: 0.4690
# Epoch 36/1000
# 48/50 [===========================>..] - ETA: 0s - loss: 0.0287 - auc: 0.8837
# Epoch 36: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0286 - auc: 0.8851 - val_loss: 0.0465 - val_auc: 0.6715
# Epoch 37/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0282 - auc: 0.8883
# Epoch 37: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0282 - auc: 0.8881 - val_loss: 0.0572 - val_auc: 0.8032
# Epoch 38/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0275 - auc: 0.8945
# Epoch 38: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0275 - auc: 0.8946 - val_loss: 0.0295 - val_auc: 0.8789
# Epoch 39/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0279 - auc: 0.8904
# Epoch 39: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0279 - auc: 0.8901 - val_loss: 0.0644 - val_auc: 0.5769
# Epoch 40/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0275 - auc: 0.8964
# Epoch 40: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0275 - auc: 0.8970 - val_loss: 0.0594 - val_auc: 0.8326
# Epoch 41/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0285 - auc: 0.8862
# Epoch 41: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0285 - auc: 0.8852 - val_loss: 0.1221 - val_auc: 0.4882
# Epoch 42/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0283 - auc: 0.8880
# Epoch 42: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0283 - auc: 0.8876 - val_loss: 0.3326 - val_auc: 0.4770
# Epoch 43/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0288 - auc: 0.8829
# Epoch 43: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0288 - auc: 0.8830 - val_loss: 0.0795 - val_auc: 0.6854
# Epoch 44/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0305 - auc: 0.8636
# Epoch 44: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0305 - auc: 0.8640 - val_loss: 0.1470 - val_auc: 0.4595
# Epoch 45/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0286 - auc: 0.8849
# Epoch 45: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0286 - auc: 0.8852 - val_loss: 0.0542 - val_auc: 0.8350
# Epoch 46/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0277 - auc: 0.8943
# Epoch 46: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0276 - auc: 0.8950 - val_loss: 0.0292 - val_auc: 0.8823
# Epoch 47/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0274 - auc: 0.8960
# Epoch 47: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0274 - auc: 0.8962 - val_loss: 0.2400 - val_auc: 0.4667
# Epoch 48/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0280 - auc: 0.8890
# Epoch 48: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0280 - auc: 0.8898 - val_loss: 0.0886 - val_auc: 0.7616
# Epoch 49/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0273 - auc: 0.8967
# Epoch 49: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0273 - auc: 0.8955 - val_loss: 0.0759 - val_auc: 0.8009
# Epoch 50/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0261 - auc: 0.9069
# Epoch 50: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0261 - auc: 0.9069 - val_loss: 0.0539 - val_auc: 0.8066
# Epoch 51/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0279 - auc: 0.8913
# Epoch 51: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0279 - auc: 0.8920 - val_loss: 0.0418 - val_auc: 0.8283
# Epoch 52/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0270 - auc: 0.8983
# Epoch 52: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0270 - auc: 0.8984 - val_loss: 3.4055 - val_auc: 0.4378
# Epoch 53/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0258 - auc: 0.9093
# Epoch 53: val_auc did not improve from 0.88483
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0258 - auc: 0.9099 - val_loss: 0.0337 - val_auc: 0.8457
# Epoch 54/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0255 - auc: 0.9132
# Epoch 54: val_auc improved from 0.88483 to 0.91293, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 1s 23ms/step - loss: 0.0255 - auc: 0.9133 - val_loss: 0.0256 - val_auc: 0.9129
# Epoch 55/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0267 - auc: 0.9021
# Epoch 55: val_auc did not improve from 0.91293
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0268 - auc: 0.9012 - val_loss: 0.9472 - val_auc: 0.4818
# Epoch 56/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0259 - auc: 0.9088
# Epoch 56: val_auc did not improve from 0.91293
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0259 - auc: 0.9087 - val_loss: 0.0308 - val_auc: 0.8869
# Epoch 57/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0273 - auc: 0.8963
# Epoch 57: val_auc did not improve from 0.91293
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0273 - auc: 0.8969 - val_loss: 0.0977 - val_auc: 0.7931
# Epoch 58/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0256 - auc: 0.9110
# Epoch 58: val_auc did not improve from 0.91293
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0256 - auc: 0.9106 - val_loss: 0.1161 - val_auc: 0.7064
# Epoch 59/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0300 - auc: 0.8707
# Epoch 59: val_auc did not improve from 0.91293
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0300 - auc: 0.8704 - val_loss: 0.0969 - val_auc: 0.7734
# Epoch 60/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0266 - auc: 0.9013
# Epoch 60: val_auc improved from 0.91293 to 0.92510, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0266 - auc: 0.9018 - val_loss: 0.0244 - val_auc: 0.9251
# Epoch 61/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0259 - auc: 0.9084
# Epoch 61: val_auc did not improve from 0.92510
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0258 - auc: 0.9092 - val_loss: 4.0535 - val_auc: 0.3349
# Epoch 62/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0256 - auc: 0.9137
# Epoch 62: val_auc did not improve from 0.92510
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0256 - auc: 0.9138 - val_loss: 0.0703 - val_auc: 0.8140
# Epoch 63/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0266 - auc: 0.9029
# Epoch 63: val_auc did not improve from 0.92510
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0266 - auc: 0.9031 - val_loss: 1.4116 - val_auc: 0.4745
# Epoch 64/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0237 - auc: 0.9260
# Epoch 64: val_auc did not improve from 0.92510
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0237 - auc: 0.9260 - val_loss: 3.0293 - val_auc: 0.4707
# Epoch 65/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0242 - auc: 0.9222
# Epoch 65: val_auc did not improve from 0.92510
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0242 - auc: 0.9218 - val_loss: 0.1608 - val_auc: 0.4922
# Epoch 66/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0246 - auc: 0.9191
# Epoch 66: val_auc did not improve from 0.92510
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0246 - auc: 0.9188 - val_loss: 0.1114 - val_auc: 0.6802
# Epoch 67/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0274 - auc: 0.8957
# Epoch 67: val_auc did not improve from 0.92510
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0274 - auc: 0.8954 - val_loss: 0.3708 - val_auc: 0.4919
# Epoch 68/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0250 - auc: 0.9161
# Epoch 68: val_auc did not improve from 0.92510
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0250 - auc: 0.9162 - val_loss: 5.7703 - val_auc: 0.3198
# Epoch 69/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0236 - auc: 0.9268
# Epoch 69: val_auc did not improve from 0.92510
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0236 - auc: 0.9268 - val_loss: 0.0285 - val_auc: 0.9132
# Epoch 70/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0233 - auc: 0.9283
# Epoch 70: val_auc did not improve from 0.92510
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0234 - auc: 0.9275 - val_loss: 0.1576 - val_auc: 0.5258
# Epoch 71/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0232 - auc: 0.9297
# Epoch 71: val_auc did not improve from 0.92510
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0232 - auc: 0.9296 - val_loss: 0.1868 - val_auc: 0.5138
# Epoch 72/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0225 - auc: 0.9341
# Epoch 72: val_auc did not improve from 0.92510
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0225 - auc: 0.9336 - val_loss: 1.9867 - val_auc: 0.4931
# Epoch 73/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0232 - auc: 0.9288
# Epoch 73: val_auc improved from 0.92510 to 0.92696, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0233 - auc: 0.9285 - val_loss: 0.0248 - val_auc: 0.9270
# Epoch 74/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0239 - auc: 0.9255
# Epoch 74: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0239 - auc: 0.9254 - val_loss: 0.1396 - val_auc: 0.5363
# Epoch 75/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0225 - auc: 0.9341
# Epoch 75: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0225 - auc: 0.9345 - val_loss: 0.1266 - val_auc: 0.5536
# Epoch 76/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0230 - auc: 0.9312
# Epoch 76: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0230 - auc: 0.9317 - val_loss: 0.0520 - val_auc: 0.8799
# Epoch 77/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0221 - auc: 0.9362
# Epoch 77: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0221 - auc: 0.9364 - val_loss: 0.1417 - val_auc: 0.7922
# Epoch 78/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0215 - auc: 0.9398
# Epoch 78: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0214 - auc: 0.9402 - val_loss: 0.0254 - val_auc: 0.9228
# Epoch 79/1000
# 47/50 [===========================>..] - ETA: 0s - loss: 0.0232 - auc: 0.9287
# Epoch 79: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0233 - auc: 0.9278 - val_loss: 2.9305 - val_auc: 0.4737
# Epoch 80/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0219 - auc: 0.9375
# Epoch 80: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0219 - auc: 0.9380 - val_loss: 0.0405 - val_auc: 0.8173
# Epoch 81/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0220 - auc: 0.9374
# Epoch 81: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0220 - auc: 0.9369 - val_loss: 0.0490 - val_auc: 0.7507
# Epoch 82/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0218 - auc: 0.9386
# Epoch 82: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0218 - auc: 0.9387 - val_loss: 0.1194 - val_auc: 0.5664
# Epoch 83/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0217 - auc: 0.9385
# Epoch 83: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0217 - auc: 0.9388 - val_loss: 0.0264 - val_auc: 0.9236
# Epoch 84/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0237 - auc: 0.9256
# Epoch 84: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0237 - auc: 0.9257 - val_loss: 0.1365 - val_auc: 0.8183
# Epoch 85/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0216 - auc: 0.9395
# Epoch 85: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0216 - auc: 0.9390 - val_loss: 0.1806 - val_auc: 0.7401
# Epoch 86/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0213 - auc: 0.9417
# Epoch 86: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0213 - auc: 0.9421 - val_loss: 0.0595 - val_auc: 0.8748
# Epoch 87/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0201 - auc: 0.9481
# Epoch 87: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0201 - auc: 0.9484 - val_loss: 0.0872 - val_auc: 0.6278
# Epoch 88/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0207 - auc: 0.9447
# Epoch 88: val_auc did not improve from 0.92696
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0207 - auc: 0.9451 - val_loss: 0.0620 - val_auc: 0.8751
# Epoch 89/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0205 - auc: 0.9464
# Epoch 89: val_auc improved from 0.92696 to 0.93395, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0205 - auc: 0.9469 - val_loss: 0.0231 - val_auc: 0.9339
# Epoch 90/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0205 - auc: 0.9463
# Epoch 90: val_auc did not improve from 0.93395
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0205 - auc: 0.9464 - val_loss: 0.0245 - val_auc: 0.9305
# Epoch 91/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0204 - auc: 0.9465
# Epoch 91: val_auc did not improve from 0.93395
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0204 - auc: 0.9467 - val_loss: 0.1823 - val_auc: 0.6957
# Epoch 92/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0214 - auc: 0.9403
# Epoch 92: val_auc did not improve from 0.93395
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0214 - auc: 0.9403 - val_loss: 0.5336 - val_auc: 0.5010
# Epoch 93/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0190 - auc: 0.9544
# Epoch 93: val_auc did not improve from 0.93395
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0190 - auc: 0.9540 - val_loss: 0.0243 - val_auc: 0.9279
# Epoch 94/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0209 - auc: 0.9438
# Epoch 94: val_auc did not improve from 0.93395
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0209 - auc: 0.9440 - val_loss: 0.0773 - val_auc: 0.6802
# Epoch 95/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0197 - auc: 0.9502
# Epoch 95: val_auc did not improve from 0.93395
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0197 - auc: 0.9505 - val_loss: 0.0480 - val_auc: 0.8843
# Epoch 96/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0205 - auc: 0.9461
# Epoch 96: val_auc did not improve from 0.93395
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0205 - auc: 0.9460 - val_loss: 0.1777 - val_auc: 0.5238
# Epoch 97/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0194 - auc: 0.9523
# Epoch 97: val_auc improved from 0.93395 to 0.93458, saving model to best_model/stcan2/0\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0194 - auc: 0.9516 - val_loss: 0.0238 - val_auc: 0.9346
# Epoch 98/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0208 - auc: 0.9440
# Epoch 98: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0207 - auc: 0.9445 - val_loss: 0.0579 - val_auc: 0.8670
# Epoch 99/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0187 - auc: 0.9563
# Epoch 99: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0187 - auc: 0.9557 - val_loss: 0.1860 - val_auc: 0.8026
# Epoch 100/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0200 - auc: 0.9483
# Epoch 100: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0200 - auc: 0.9478 - val_loss: 3.9569 - val_auc: 0.3327
# Epoch 101/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0200 - auc: 0.9481
# Epoch 101: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0200 - auc: 0.9483 - val_loss: 0.1086 - val_auc: 0.8456
# Epoch 102/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0196 - auc: 0.9514
# Epoch 102: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0196 - auc: 0.9517 - val_loss: 0.0330 - val_auc: 0.9050
# Epoch 103/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0195 - auc: 0.9521
# Epoch 103: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0195 - auc: 0.9520 - val_loss: 0.1335 - val_auc: 0.6085
# Epoch 104/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0212 - auc: 0.9416
# Epoch 104: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0212 - auc: 0.9421 - val_loss: 0.1754 - val_auc: 0.8130
# Epoch 105/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0189 - auc: 0.9551
# Epoch 105: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0189 - auc: 0.9554 - val_loss: 0.1018 - val_auc: 0.8423
# Epoch 106/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0200 - auc: 0.9485
# Epoch 106: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0200 - auc: 0.9483 - val_loss: 0.1819 - val_auc: 0.5421
# Epoch 107/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0193 - auc: 0.9521
# Epoch 107: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0193 - auc: 0.9526 - val_loss: 2.1499 - val_auc: 0.4785
# Epoch 108/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0211 - auc: 0.9424
# Epoch 108: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0210 - auc: 0.9429 - val_loss: 0.0306 - val_auc: 0.8726
# Epoch 109/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0193 - auc: 0.9526
# Epoch 109: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0193 - auc: 0.9526 - val_loss: 1.0185 - val_auc: 0.4958
# Epoch 110/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0174 - auc: 0.9620
# Epoch 110: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0174 - auc: 0.9620 - val_loss: 0.0272 - val_auc: 0.9176
# Epoch 111/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0202 - auc: 0.9477
# Epoch 111: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0202 - auc: 0.9482 - val_loss: 0.1814 - val_auc: 0.8081
# Epoch 112/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0181 - auc: 0.9595
# Epoch 112: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0181 - auc: 0.9595 - val_loss: 1.0917 - val_auc: 0.4986
# Epoch 113/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0189 - auc: 0.9546
# Epoch 113: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0189 - auc: 0.9544 - val_loss: 0.6221 - val_auc: 0.5039
# Epoch 114/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0179 - auc: 0.9597
# Epoch 114: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0179 - auc: 0.9596 - val_loss: 0.9782 - val_auc: 0.4963
# Epoch 115/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0207 - auc: 0.9451
# Epoch 115: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0207 - auc: 0.9451 - val_loss: 0.2392 - val_auc: 0.7162
# Epoch 116/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0174 - auc: 0.9620
# Epoch 116: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0174 - auc: 0.9619 - val_loss: 0.1101 - val_auc: 0.8523
# Epoch 117/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0179 - auc: 0.9597
# Epoch 117: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0179 - auc: 0.9598 - val_loss: 0.0798 - val_auc: 0.6714
# Epoch 118/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0172 - auc: 0.9630
# Epoch 118: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0173 - auc: 0.9615 - val_loss: 0.1406 - val_auc: 0.5650
# Epoch 119/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0173 - auc: 0.9620
# Epoch 119: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0173 - auc: 0.9621 - val_loss: 0.0363 - val_auc: 0.9113
# Epoch 120/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0182 - auc: 0.9581
# Epoch 120: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0182 - auc: 0.9580 - val_loss: 0.1417 - val_auc: 0.8313
# Epoch 121/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0168 - auc: 0.9644
# Epoch 121: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0168 - auc: 0.9647 - val_loss: 1.1928 - val_auc: 0.4692
# Epoch 122/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0175 - auc: 0.9610
# Epoch 122: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0175 - auc: 0.9606 - val_loss: 0.5413 - val_auc: 0.5027
# Epoch 123/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0173 - auc: 0.9624
# Epoch 123: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0173 - auc: 0.9624 - val_loss: 0.0271 - val_auc: 0.9269
# Epoch 124/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0170 - auc: 0.9631
# Epoch 124: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0171 - auc: 0.9629 - val_loss: 0.0457 - val_auc: 0.8973
# Epoch 125/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0169 - auc: 0.9630
# Epoch 125: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0169 - auc: 0.9627 - val_loss: 0.2825 - val_auc: 0.7919
# Epoch 126/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0195 - auc: 0.9504
# Epoch 126: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0195 - auc: 0.9503 - val_loss: 0.0560 - val_auc: 0.8884
# Epoch 127/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0165 - auc: 0.9654
# Epoch 127: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0165 - auc: 0.9655 - val_loss: 0.1630 - val_auc: 0.5518
# Epoch 128/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0169 - auc: 0.9637
# Epoch 128: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0169 - auc: 0.9626 - val_loss: 2.6849 - val_auc: 0.4810
# Epoch 129/1000
# 48/50 [===========================>..] - ETA: 0s - loss: 0.0176 - auc: 0.9609
# Epoch 129: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0176 - auc: 0.9612 - val_loss: 0.2461 - val_auc: 0.5075
# Epoch 130/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0161 - auc: 0.9672
# Epoch 130: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0161 - auc: 0.9672 - val_loss: 0.0535 - val_auc: 0.8986
# Epoch 131/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0173 - auc: 0.9619
# Epoch 131: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0174 - auc: 0.9612 - val_loss: 0.3243 - val_auc: 0.4946
# Epoch 132/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0167 - auc: 0.9645
# Epoch 132: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0167 - auc: 0.9648 - val_loss: 0.1731 - val_auc: 0.8419
# Epoch 133/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0163 - auc: 0.9663
# Epoch 133: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0163 - auc: 0.9665 - val_loss: 1.2377 - val_auc: 0.4913
# Epoch 134/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0163 - auc: 0.9667
# Epoch 134: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0163 - auc: 0.9660 - val_loss: 0.0985 - val_auc: 0.8636
# Epoch 135/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0168 - auc: 0.9636
# Epoch 135: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0168 - auc: 0.9637 - val_loss: 0.0288 - val_auc: 0.9273
# Epoch 136/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0160 - auc: 0.9673
# Epoch 136: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0160 - auc: 0.9671 - val_loss: 2.1991 - val_auc: 0.4747
# Epoch 137/1000
# 48/50 [===========================>..] - ETA: 0s - loss: 0.0181 - auc: 0.9587
# Epoch 137: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0180 - auc: 0.9592 - val_loss: 0.2889 - val_auc: 0.7778
# Epoch 138/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0162 - auc: 0.9669
# Epoch 138: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0162 - auc: 0.9660 - val_loss: 0.2274 - val_auc: 0.7963
# Epoch 139/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0160 - auc: 0.9668
# Epoch 139: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0160 - auc: 0.9669 - val_loss: 0.4231 - val_auc: 0.4903
# Epoch 140/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0158 - auc: 0.9684
# Epoch 140: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0158 - auc: 0.9684 - val_loss: 0.0379 - val_auc: 0.8878
# Epoch 141/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0163 - auc: 0.9656
# Epoch 141: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0163 - auc: 0.9658 - val_loss: 0.1675 - val_auc: 0.8561
# Epoch 142/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0152 - auc: 0.9704
# Epoch 142: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0153 - auc: 0.9701 - val_loss: 0.3137 - val_auc: 0.7820
# Epoch 143/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0164 - auc: 0.9661
# Epoch 143: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0164 - auc: 0.9660 - val_loss: 0.6818 - val_auc: 0.4760
# Epoch 144/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0169 - auc: 0.9636
# Epoch 144: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0168 - auc: 0.9639 - val_loss: 0.0274 - val_auc: 0.9305
# Epoch 145/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0153 - auc: 0.9698
# Epoch 145: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0153 - auc: 0.9700 - val_loss: 2.9142 - val_auc: 0.4611
# Epoch 146/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0140 - auc: 0.9754
# Epoch 146: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0140 - auc: 0.9753 - val_loss: 0.7898 - val_auc: 0.4822
# Epoch 147/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0165 - auc: 0.9654
# Epoch 147: val_auc did not improve from 0.93458
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0166 - auc: 0.9644 - val_loss: 0.3910 - val_auc: 0.6871
# Epoch 147: early stopping
# 50/50 [==============================] - 1s 4ms/step
# 50/50 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 5ms/step
# Fold 2/5
# stcan2 <keras.engine.functional.Functional object at 0x00000236D9C3A580> Training in Fold: 2
# Epoch 1/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0204 - auc: 0.9474
# Epoch 1: val_auc improved from -inf to 0.93538, saving model to best_model/stcan2/1\best_weights.hdf5
# 50/50 [==============================] - 1s 24ms/step - loss: 0.0204 - auc: 0.9478 - val_loss: 0.0247 - val_auc: 0.9354
# Epoch 2/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0198 - auc: 0.9497
# Epoch 2: val_auc did not improve from 0.93538
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0198 - auc: 0.9499 - val_loss: 4.4363 - val_auc: 0.3263
# Epoch 3/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0206 - auc: 0.9455
# Epoch 3: val_auc did not improve from 0.93538
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0207 - auc: 0.9448 - val_loss: 0.3216 - val_auc: 0.5167
# Epoch 4/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0206 - auc: 0.9456
# Epoch 4: val_auc did not improve from 0.93538
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0206 - auc: 0.9457 - val_loss: 0.0571 - val_auc: 0.8899
# Epoch 5/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0197 - auc: 0.9506
# Epoch 5: val_auc did not improve from 0.93538
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0197 - auc: 0.9505 - val_loss: 0.1605 - val_auc: 0.8461
# Epoch 6/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0216 - auc: 0.9402
# Epoch 6: val_auc improved from 0.93538 to 0.94359, saving model to best_model/stcan2/1\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0216 - auc: 0.9392 - val_loss: 0.0216 - val_auc: 0.9436
# Epoch 7/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0194 - auc: 0.9519
# Epoch 7: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0194 - auc: 0.9518 - val_loss: 3.5410 - val_auc: 0.3948
# Epoch 8/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0198 - auc: 0.9496
# Epoch 8: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0198 - auc: 0.9496 - val_loss: 2.2174 - val_auc: 0.4930
# Epoch 9/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0196 - auc: 0.9510
# Epoch 9: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0196 - auc: 0.9510 - val_loss: 1.2637 - val_auc: 0.4867
# Epoch 10/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0203 - auc: 0.9469
# Epoch 10: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0203 - auc: 0.9472 - val_loss: 1.0856 - val_auc: 0.5002
# Epoch 11/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0188 - auc: 0.9551
# Epoch 11: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0188 - auc: 0.9555 - val_loss: 0.0432 - val_auc: 0.8351
# Epoch 12/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0197 - auc: 0.9496
# Epoch 12: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0197 - auc: 0.9500 - val_loss: 0.1763 - val_auc: 0.8441
# Epoch 13/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0182 - auc: 0.9580
# Epoch 13: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0182 - auc: 0.9579 - val_loss: 1.6233 - val_auc: 0.4914
# Epoch 14/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0183 - auc: 0.9568
# Epoch 14: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0183 - auc: 0.9567 - val_loss: 0.2617 - val_auc: 0.5208
# Epoch 15/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0184 - auc: 0.9570
# Epoch 15: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0184 - auc: 0.9569 - val_loss: 0.1205 - val_auc: 0.8320
# Epoch 16/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0183 - auc: 0.9578
# Epoch 16: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0183 - auc: 0.9581 - val_loss: 0.2342 - val_auc: 0.7711
# Epoch 17/1000
# 48/50 [===========================>..] - ETA: 0s - loss: 0.0181 - auc: 0.9589
# Epoch 17: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0179 - auc: 0.9600 - val_loss: 0.1217 - val_auc: 0.8487
# Epoch 18/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0180 - auc: 0.9593
# Epoch 18: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0180 - auc: 0.9595 - val_loss: 2.1491 - val_auc: 0.4933
# Epoch 19/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0183 - auc: 0.9577
# Epoch 19: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0183 - auc: 0.9577 - val_loss: 0.3874 - val_auc: 0.5168
# Epoch 20/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0175 - auc: 0.9611
# Epoch 20: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0175 - auc: 0.9612 - val_loss: 1.0568 - val_auc: 0.4980
# Epoch 21/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0187 - auc: 0.9559
# Epoch 21: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0187 - auc: 0.9559 - val_loss: 0.0757 - val_auc: 0.8578
# Epoch 22/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0166 - auc: 0.9654
# Epoch 22: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0166 - auc: 0.9655 - val_loss: 1.3077 - val_auc: 0.4978
# Epoch 23/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0174 - auc: 0.9613
# Epoch 23: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0175 - auc: 0.9609 - val_loss: 0.1025 - val_auc: 0.8520
# Epoch 24/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0189 - auc: 0.9536
# Epoch 24: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0189 - auc: 0.9537 - val_loss: 0.0272 - val_auc: 0.9213
# Epoch 25/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0183 - auc: 0.9570
# Epoch 25: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0183 - auc: 0.9571 - val_loss: 0.0389 - val_auc: 0.9151
# Epoch 26/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0176 - auc: 0.9605
# Epoch 26: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0176 - auc: 0.9609 - val_loss: 0.0244 - val_auc: 0.9285
# Epoch 27/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0167 - auc: 0.9650
# Epoch 27: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0167 - auc: 0.9651 - val_loss: 0.0444 - val_auc: 0.7899
# Epoch 28/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0172 - auc: 0.9629
# Epoch 28: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0172 - auc: 0.9629 - val_loss: 0.1201 - val_auc: 0.6913
# Epoch 29/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0185 - auc: 0.9579
# Epoch 29: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0185 - auc: 0.9582 - val_loss: 0.5268 - val_auc: 0.5045
# Epoch 30/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0160 - auc: 0.9683
# Epoch 30: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0160 - auc: 0.9680 - val_loss: 1.4007 - val_auc: 0.4969
# Epoch 31/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0171 - auc: 0.9635
# Epoch 31: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0170 - auc: 0.9637 - val_loss: 0.0469 - val_auc: 0.8591
# Epoch 32/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0175 - auc: 0.9606
# Epoch 32: val_auc did not improve from 0.94359
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0176 - auc: 0.9602 - val_loss: 2.3426 - val_auc: 0.4844
# Epoch 33/1000
# ...
# Epoch 16: val_auc did not improve from 0.92228
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0174 - auc: 0.9619 - val_loss: 0.1036 - val_auc: 0.8282
# Epoch 17/1000
# 48/50 [===========================>..] - ETA: 0s - loss: 0.0159 - auc: 0.9692
# Epoch 17: val_auc did not improve from 0.92228
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0159 - auc: 0.9693 - val_loss: 2.8080 - val_auc: 0.4888
# Epoch 18/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0171 - auc: 0.9639
# Epoch 18: val_auc did not improve from 0.92228
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0171 - auc: 0.9640 - val_loss: 0.0798 - val_auc: 0.7150
# Epoch 19/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0170 - auc: 0.9638
# Epoch 19: val_auc did not improve from 0.92228
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0170 - auc: 0.9639 - val_loss: 0.0328 - val_auc: 0.9201
# Epoch 20/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0150 - auc: 0.9722
# Epoch 20: val_auc improved from 0.92228 to 0.95020, saving model to best_model/stcan2/4\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0150 - auc: 0.9724 - val_loss: 0.0255 - val_auc: 0.9502
# Epoch 21/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0167 - auc: 0.9643
# Epoch 21: val_auc did not improve from 0.95020
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0167 - auc: 0.9642 - val_loss: 0.0751 - val_auc: 0.8762
# Epoch 22/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0157 - auc: 0.9698
# Epoch 22: val_auc did not improve from 0.95020
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0157 - auc: 0.9697 - val_loss: 0.0855 - val_auc: 0.8706
# Epoch 23/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0156 - auc: 0.9699
# Epoch 23: val_auc did not improve from 0.95020
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0156 - auc: 0.9696 - val_loss: 0.0575 - val_auc: 0.8114
# Epoch 24/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0173 - auc: 0.9626
# Epoch 24: val_auc improved from 0.95020 to 0.95484, saving model to best_model/stcan2/4\best_weights.hdf5
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0173 - auc: 0.9625 - val_loss: 0.0201 - val_auc: 0.9548
# Epoch 25/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0156 - auc: 0.9701
# Epoch 25: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0156 - auc: 0.9699 - val_loss: 0.6906 - val_auc: 0.4995
# Epoch 26/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0159 - auc: 0.9688
# Epoch 26: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0159 - auc: 0.9684 - val_loss: 0.0728 - val_auc: 0.8765
# Epoch 27/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0159 - auc: 0.9683
# Epoch 27: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0159 - auc: 0.9685 - val_loss: 0.2286 - val_auc: 0.5308
# Epoch 28/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0146 - auc: 0.9738
# Epoch 28: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0147 - auc: 0.9728 - val_loss: 0.1518 - val_auc: 0.8379
# Epoch 29/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0155 - auc: 0.9711
# Epoch 29: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0155 - auc: 0.9708 - val_loss: 0.1457 - val_auc: 0.5776
# Epoch 30/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0208 - auc: 0.9493
# Epoch 30: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0209 - auc: 0.9490 - val_loss: 0.0731 - val_auc: 0.6777
# Epoch 31/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0299 - auc: 0.8658
# Epoch 31: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0299 - auc: 0.8660 - val_loss: 0.0467 - val_auc: 0.8295
# Epoch 32/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0245 - auc: 0.9193
# Epoch 32: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0245 - auc: 0.9191 - val_loss: 2.2704 - val_auc: 0.4995
# Epoch 33/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0202 - auc: 0.9478
# Epoch 33: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0202 - auc: 0.9477 - val_loss: 3.2957 - val_auc: 0.4543
# Epoch 34/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0194 - auc: 0.9508
# Epoch 34: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0195 - auc: 0.9498 - val_loss: 5.7509 - val_auc: 0.3223
# Epoch 35/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0179 - auc: 0.9591
# Epoch 35: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0179 - auc: 0.9593 - val_loss: 3.6615 - val_auc: 0.4082
# Epoch 36/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0187 - auc: 0.9558
# Epoch 36: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0187 - auc: 0.9562 - val_loss: 2.3836 - val_auc: 0.4977
# Epoch 37/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0216 - auc: 0.9407
# Epoch 37: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0216 - auc: 0.9410 - val_loss: 0.1243 - val_auc: 0.6931
# Epoch 38/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0185 - auc: 0.9568
# Epoch 38: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0185 - auc: 0.9571 - val_loss: 0.0551 - val_auc: 0.8906
# Epoch 39/1000
# 48/50 [===========================>..] - ETA: 0s - loss: 0.0175 - auc: 0.9628
# Epoch 39: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0174 - auc: 0.9628 - val_loss: 5.5684 - val_auc: 0.3223
# Epoch 40/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0164 - auc: 0.9667
# Epoch 40: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0164 - auc: 0.9669 - val_loss: 0.0294 - val_auc: 0.9407
# Epoch 41/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0201 - auc: 0.9578
# Epoch 41: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0201 - auc: 0.9571 - val_loss: 3.7613 - val_auc: 0.3809
# Epoch 42/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0174 - auc: 0.9618
# Epoch 42: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0174 - auc: 0.9615 - val_loss: 5.5845 - val_auc: 0.3223
# Epoch 43/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0175 - auc: 0.9611
# Epoch 43: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0175 - auc: 0.9614 - val_loss: 0.1585 - val_auc: 0.5381
# Epoch 44/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0164 - auc: 0.9665
# Epoch 44: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0164 - auc: 0.9664 - val_loss: 0.0527 - val_auc: 0.8332
# Epoch 45/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0170 - auc: 0.9641
# Epoch 45: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0170 - auc: 0.9636 - val_loss: 0.0946 - val_auc: 0.8202
# Epoch 46/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0174 - auc: 0.9613
# Epoch 46: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0174 - auc: 0.9611 - val_loss: 0.1152 - val_auc: 0.7868
# Epoch 47/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0148 - auc: 0.9734
# Epoch 47: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0148 - auc: 0.9737 - val_loss: 0.0751 - val_auc: 0.8073
# Epoch 48/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0184 - auc: 0.9581
# Epoch 48: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0185 - auc: 0.9573 - val_loss: 0.0266 - val_auc: 0.9097
# Epoch 49/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0199 - auc: 0.9489
# Epoch 49: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0200 - auc: 0.9488 - val_loss: 6.0861 - val_auc: 0.3223
# Epoch 50/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0180 - auc: 0.9599
# Epoch 50: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0180 - auc: 0.9599 - val_loss: 0.0243 - val_auc: 0.9399
# Epoch 51/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0169 - auc: 0.9645
# Epoch 51: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0169 - auc: 0.9637 - val_loss: 0.0831 - val_auc: 0.6529
# Epoch 52/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0168 - auc: 0.9642
# Epoch 52: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0168 - auc: 0.9644 - val_loss: 0.0667 - val_auc: 0.7626
# Epoch 53/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0158 - auc: 0.9693
# Epoch 53: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0158 - auc: 0.9692 - val_loss: 0.6845 - val_auc: 0.4975
# Epoch 54/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0171 - auc: 0.9638
# Epoch 54: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0171 - auc: 0.9641 - val_loss: 0.0697 - val_auc: 0.7185
# Epoch 55/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0147 - auc: 0.9732
# Epoch 55: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0148 - auc: 0.9724 - val_loss: 0.0419 - val_auc: 0.9026
# Epoch 56/1000
# 48/50 [===========================>..] - ETA: 0s - loss: 0.0149 - auc: 0.9727
# Epoch 56: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0147 - auc: 0.9733 - val_loss: 0.0734 - val_auc: 0.8918
# Epoch 57/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0199 - auc: 0.9494
# Epoch 57: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0199 - auc: 0.9495 - val_loss: 0.2234 - val_auc: 0.7498
# Epoch 58/1000
# 48/50 [===========================>..] - ETA: 0s - loss: 0.0140 - auc: 0.9759
# Epoch 58: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0139 - auc: 0.9764 - val_loss: 0.0932 - val_auc: 0.8824
# Epoch 59/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0149 - auc: 0.9722
# Epoch 59: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0149 - auc: 0.9716 - val_loss: 0.0430 - val_auc: 0.9116
# Epoch 60/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0143 - auc: 0.9747
# Epoch 60: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0143 - auc: 0.9743 - val_loss: 0.0246 - val_auc: 0.9272
# Epoch 61/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0165 - auc: 0.9666
# Epoch 61: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0165 - auc: 0.9666 - val_loss: 0.1183 - val_auc: 0.8200
# Epoch 62/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0151 - auc: 0.9726
# Epoch 62: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0150 - auc: 0.9727 - val_loss: 0.2151 - val_auc: 0.5353
# Epoch 63/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0135 - auc: 0.9773
# Epoch 63: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0136 - auc: 0.9767 - val_loss: 0.0543 - val_auc: 0.8445
# Epoch 64/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0133 - auc: 0.9784
# Epoch 64: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0133 - auc: 0.9785 - val_loss: 0.0278 - val_auc: 0.9379
# Epoch 65/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0148 - auc: 0.9731
# Epoch 65: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0148 - auc: 0.9733 - val_loss: 0.0369 - val_auc: 0.9247
# Epoch 66/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0144 - auc: 0.9742
# Epoch 66: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0144 - auc: 0.9739 - val_loss: 0.0340 - val_auc: 0.9228
# Epoch 67/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0141 - auc: 0.9759
# Epoch 67: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0141 - auc: 0.9761 - val_loss: 0.0281 - val_auc: 0.9174
# Epoch 68/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0152 - auc: 0.9717
# Epoch 68: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0152 - auc: 0.9717 - val_loss: 2.0815 - val_auc: 0.4808
# Epoch 69/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0135 - auc: 0.9776
# Epoch 69: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0135 - auc: 0.9776 - val_loss: 0.0295 - val_auc: 0.9347
# Epoch 70/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0132 - auc: 0.9784
# Epoch 70: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 15ms/step - loss: 0.0132 - auc: 0.9786 - val_loss: 0.0927 - val_auc: 0.7850
# Epoch 71/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0153 - auc: 0.9714
# Epoch 71: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0153 - auc: 0.9716 - val_loss: 0.1432 - val_auc: 0.8243
# Epoch 72/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0145 - auc: 0.9751
# Epoch 72: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0145 - auc: 0.9749 - val_loss: 0.0289 - val_auc: 0.9308
# Epoch 73/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0150 - auc: 0.9727
# Epoch 73: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0150 - auc: 0.9729 - val_loss: 0.0330 - val_auc: 0.9262
# Epoch 74/1000
# 49/50 [============================>.] - ETA: 0s - loss: 0.0122 - auc: 0.9814
# Epoch 74: val_auc did not improve from 0.95484
# 50/50 [==============================] - 1s 16ms/step - loss: 0.0122 - auc: 0.9816 - val_loss: 0.0859 - val_auc: 0.8962
# Epoch 74: early stopping
# 50/50 [==============================] - 0s 5ms/step
# 50/50 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 4ms/step
# 13/13 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 5ms/step
# 13/13 [==============================] - 0s 5ms/step
#
# Final 5-Fold Cross-Validation Results:
# Average Accuracy: 0.8817 ± 0.0159
# Average F1 Score: 0.7906 ± 0.0416
# Average ROC AUC: 0.9369 ± 0.0091
# Average MCC: 0.7251 ± 0.0359

# %%
model_eval_test
# Out:
#           precision    recall  f1-score  accuracy       ROC        PR  \
# 0_stcan2   0.920455  0.642857  0.757009  0.868020  0.919954  0.876360
# 1_stcan2   0.973333  0.579365  0.726368  0.860406  0.942342  0.914520
# 2_stcan2   0.931373  0.753968  0.833333  0.903553  0.935501  0.915737
# 3_stcan2   0.882883  0.771654  0.823529  0.893401  0.945413  0.917417
# 4_stcan2   0.840336  0.787402  0.813008  0.883249  0.941196  0.913591
#
#                MCC
# 0_stcan2  0.690639
# 1_stcan2  0.679436
# 2_stcan2  0.775001
# 3_stcan2  0.751138
# 4_stcan2  0.729082

# %%
zzz

# %%
# model_eval_test.to_csv('stcan4.csv')
